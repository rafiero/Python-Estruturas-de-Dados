# %% [markdown]
# # Lista encadeada simples

# %%
class No:
  def __init__(self, valor):
    self.valor = valor
    self.proximo = None#nao existe NULL no python
  
  def mostra_no(self):
    print(self.valor)

# %%
no1 = No(1)
no1.mostra_no()
# Out:
# 1

# %%
no2 = No(2)
no2.mostra_no()
#no2.proximo
# Out:
# 2

# %%
class ListaEncadeada:
  def __init__(self):
    self.primeiro = None

  def insere_inicio(self, valor):
    novo = No(valor)
    novo.proximo = self.primeiro
    self.primeiro = novo

  def mostrar(self):
    if self.primeiro == None:
      print('A lista está vazia')
      return None
    
    atual = self.primeiro
    while atual != None:
      atual.mostra_no()
      atual = atual.proximo

  def pesquisa(self, valor):
    if self.primeiro == None:
      print('A lista está vazia')
      return None

    atual = self.primeiro
    while atual.valor != valor:
      if atual.proximo == None:
        return None
      else:
        atual = atual.proximo
    return atual

  def excluir_inicio(self):
    if self.primeiro == None:
      print('A lista está vazia')
      return None
    
    temp = self.primeiro
    self.primeiro = self.primeiro.proximo
    return temp

  def excluir_posicao(self, valor):
    if self.primeiro == None:
      print('A lista está vazia')
      return None
    
    atual = self.primeiro
    anterior = self.primeiro
    while atual.valor != valor:
      if atual.proximo == None:
        return None
      else:
        anterior = atual
        atual = atual.proximo
    
    if atual == self.primeiro:
      self.primeiro = self.primeiro.proximo
    else:
      anterior.proximo = atual.proximo
      #nao precisa excluir da memoria o objeto excluido pq o gerenciamento de memoria do python faz isso

    return atual

# %% [markdown]
# ### Insere no início

# %%
lista = ListaEncadeada()

# %%
lista.insere_inicio(1)

# %%
lista.primeiro

# %%
lista.mostrar()
# Out:
# 1

# %%
lista.insere_inicio(2)
lista.mostrar()
# Out:
# 2
# 1

# %%
lista.primeiro

# %%
lista.primeiro.mostra_no()
# Out:
# 2

# %%
lista.primeiro.proximo

# %%
lista.insere_inicio(3)
lista.insere_inicio(4)
lista.insere_inicio(4)

# %%
lista.mostrar()
# Out:
# 4
# 4
# 3
# 2
# 1

# %%
lista.primeiro.proximo.proximo.proximo.proximo

# %% [markdown]
# ### Excluir do início

# %%
lista = ListaEncadeada()
lista.insere_inicio(1)
lista.insere_inicio(2)
lista.insere_inicio(3)
lista.insere_inicio(4)
lista.insere_inicio(5)
lista.mostrar()
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
lista.excluir_inicio()
lista.mostrar()
# Out:
# 4
# 3
# 2
# 1

# %%
lista.excluir_inicio()
lista.excluir_inicio()
lista.mostrar()
# Out:
# 2
# 1

# %%
lista.excluir_inicio()
lista.mostrar()
# Out:
# 1

# %%
lista.excluir_inicio()

# %%
lista.excluir_inicio()
# Out:
# A lista está vazia

# %%
lista.mostrar()
# Out:
# A lista está vazia

# %% [markdown]
# ### Pesquisa

# %%
lista = ListaEncadeada()
lista.insere_inicio(1)
lista.insere_inicio(2)
lista.insere_inicio(3)
lista.insere_inicio(4)
lista.insere_inicio(5)
lista.mostrar()
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
pesquisa = lista.pesquisa(3)

# %%
if pesquisa != None:
  print('Encontrado: ', pesquisa.valor)
else:
  print('Não encontrado')
# Out:
# Encontrado:  3

# %% [markdown]
# ### Excluir posição

# %%
lista = ListaEncadeada()
lista.insere_inicio(1)
lista.insere_inicio(2)
lista.insere_inicio(3)
lista.insere_inicio(4)
lista.insere_inicio(5)
lista.mostrar()
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
lista.excluir_posicao(3)
lista.mostrar()
# Out:
# 5
# 4
# 2
# 1

# %%
lista.excluir_posicao(1)
lista.mostrar()
# Out:
# 5
# 4
# 2

# %%
lista.excluir_posicao(5)
lista.mostrar()
# Out:
# 4
# 2
