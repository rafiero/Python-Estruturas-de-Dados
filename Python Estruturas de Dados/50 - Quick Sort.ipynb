# %%
import random as rd

# %%
def quicksort(lista, inicio=0, fim=None):
  if fim is None:
    fim = len(lista)-1
  if inicio < fim:
    pivo = particion(lista, inicio, fim)
    #esquerda
    quicksort(lista, inicio, pivo-1)
    #direita
    quicksort(lista, pivo+1, fim)
  return lista

def particion(lista, inicio, fim):
  pivo = lista[fim]
  i = inicio
  for j in range(inicio, fim):
    if lista[j] < pivo:
      lista[j], lista[i] = lista[i], lista[j]
      i+=1
  lista[i], lista[fim] = lista[fim], lista[i]
  return i

# %%
lista = rd.sample(range(1, 1000),20)

# %%
quicksort(lista)
# Out:
# [197,
#  295,
#  366,
#  428,
#  441,
#  466,
#  475,
#  508,
#  509,
#  537,
#  599,
#  626,
#  660,
#  679,
#  703,
#  715,
#  716,
#  729,
#  763,
#  930]
