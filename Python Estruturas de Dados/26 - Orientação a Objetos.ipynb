# %% [markdown]
# ##Orientacao a Objetos
#
# classe e objeto
#
# Classe: Agrupamento de objetos similares que apresentam os mesmos atributos e metodos
#
# *  Molde de bonecos de gesso
#     *  Define o formato e o tamanho dos bonecos
#     *  O  molde eh sempre o msm, porem os objetos gerados podem ter caracteristicas diferentes, mas sempre respeitando a estrutura, mas podem ter cores diferentes
#
# *  Classe cachoro
#     * Atributos (variaveis):
#         * Cor
#         * Tamanho
#         * Nr de patas
#         * Raca
#     * Metodos (funcoes):
#         * Latir
#         * Correr
#         * Morder
#         * Brincar
