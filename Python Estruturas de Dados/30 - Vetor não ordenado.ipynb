# %% [markdown]
# # Vetor não ordenado

# %%
import numpy as np

# %%
class VetorNaoOrdenado:
  def __init__(self, capacidade):
    self.capacidade = capacidade
    self.ultima_posicao = -1
    self.valores = np.empty(self.capacidade, dtype=int)#empty retorna um novo array, mas com as posicoes alocadas, mas com valores nulos, com o tipo e o shape (dimensoes), sem inicializar as entradas

  # O(n)
  def imprime(self):
    if self.ultima_posicao == -1:
      print('O vetor está vazio')
    else:
      for i in range(self.ultima_posicao + 1):
        print(i, ' - ', self.valores[i])

  # O(1) - O(2)
  def insere(self, valor):
    if self.ultima_posicao == self.capacidade - 1:
      print('Capacidade máxima atingida')
    else:
      self.ultima_posicao += 1 
      self.valores[self.ultima_posicao] = valor 

  # O(n)
  def pesquisar(self, valor):
    for i in range(self.ultima_posicao + 1):
      if valor == self.valores[i]:
        return i
    return -1

  # O(n)
  def excluir(self, valor):
    posicao = self.pesquisar(valor)
    if posicao == -1:
      return -1
    else:
      for i in range(posicao, self.ultima_posicao):
        self.valores[i] = self.valores[i + 1]
      
      self.ultima_posicao -= 1

# %%
vetor = VetorNaoOrdenado(5)

# %%
vetor.imprime()
# Out:
# O vetor está vazio

# %%
vetor.insere(2)

# %%
vetor.imprime()
# Out:
# 0  -  2

# %%
vetor.insere(3)
vetor.insere(5)
vetor.insere(8)
vetor.insere(1)

# %%
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  5
# 3  -  8
# 4  -  1

# %%
vetor.insere(7)
# Out:
# Capacidade máxima atingida

# %%
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  5
# 3  -  8
# 4  -  1

# %%
vetor.pesquisar(8)
# Out:
# 3

# %%
vetor.pesquisar(9)
# Out:
# -1

# %%
vetor.pesquisar(3)
# Out:
# 1

# %%
vetor.ultima_posicao
# Out:
# 4

# %%
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  5
# 3  -  8
# 4  -  1

# %%
vetor.excluir(5)

# %%
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  8
# 3  -  1

# %%
vetor.excluir(1)
vetor.imprime()
# Out:
# 0  -  2
# 1  -  3
# 2  -  8

# %%
vetor.excluir(2)
vetor.imprime()
# Out:
# 0  -  3
# 1  -  8

# %%
vetor.insere(5)
vetor.insere(1)
vetor.imprime()
# Out:
# 0  -  3
# 1  -  8
# 2  -  5
# 3  -  1
